# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroLucasMF/Aulas-Ciencia-de-dados/blob/main/CodACD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
nome = (input("informe seu nome/"))
print("Olá", nome)
# Out:
# informe seu nome: p
# Olá p

# %%
palavra = (input("Digite uma palvra: "))
palavraInvertida = palavra[::-1]

print(palavraInvertida)

if palavra == palavraInvertida:
  print("é um palindro")

else:
  print("não é um palindro")
# Out:
# Digite uma palvra: papo
# opap
# não é um palindro
